# %%
from app.db.session import SessionLocal

# %%
from app.models import *
from fastapi.encoders import jsonable_encoder

# %%
db = SessionLocal()
# tag1 = Tag(name="tag1")
# note1 = db.query(Note).filter_by(id=1).first()
# note1.tags = [tag1]
# db.add_all([tag1, note1])
# db.commit()
# db.close()

# %%
tag1 = db.query(Tag).filter_by(id=1).first()
jsonable_encoder([tag1])
# Out:
# [{'name': 'happy', 'id': 1}]

# %%
tags_list = [tag1]
obj_in_data = {'id': 1,
 'title': 'My First Entry',
 'start_date': '2022-05-22',
 'color': 'pear',
 'favourite': False,
 'contents': 'string awd awd',
 'author_id': 1,
 'end_date': '2022-05-22'}
new_note = Note(**obj_in_data, tags=tags_list)

# %%
tags = db.query(Tag).all()

# %%
jsonable_encoder(tags)
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Input In [39], in <cell line: 1>()
# ----> 1 jsonable_encoder(tags)
#
# File /usr/local/lib/python3.9/site-packages/fastapi/encoders.py:121, in jsonable_encoder(obj, include, exclude, by_alias, skip_defaults, exclude_unset, exclude_defaults, exclude_none, custom_encoder, sqlalchemy_safe)
#     118     encoded_list = []
#     119     for item in obj:
#     120         encoded_list.append(
# --> 121             jsonable_encoder(
#     122                 item,
#     123                 include=include,
#     124                 exclude=exclude,
#     125                 by_alias=by_alias,
#     126                 exclude_unset=exclude_unset,
#     127                 exclude_defaults=exclude_defaults,
#     128                 exclude_none=exclude_none,
#     129                 custom_encoder=custom_encoder,
#     130                 sqlalchemy_safe=sqlalchemy_safe,
#     131             )
#     132         )
#     133     return encoded_list
#     135 if custom_encoder:
#
# File /usr/local/lib/python3.9/site-packages/fastapi/encoders.py:159, in jsonable_encoder(obj, include, exclude, by_alias, skip_defaults, exclude_unset, exclude_defaults, exclude_none, custom_encoder, sqlalchemy_safe)
#     157         errors.append(e)
#     158         raise ValueError(errors)
# --> 159 return jsonable_encoder(
#     160     data,
#     161     by_alias=by_alias,
#     162     exclude_unset=exclude_unset,
#     163     exclude_defaults=exclude_defaults,
#     164     exclude_none=exclude_none,
#     165     custom_encoder=custom_encoder,
#     166     sqlalchemy_safe=sqlalchemy_safe,
#     167 )
#
# File /usr/local/lib/python3.9/site-packages/fastapi/encoders.py:107, in jsonable_encoder(obj, include, exclude, by_alias, skip_defaults, exclude_unset, exclude_defaults, exclude_none, custom_encoder, sqlalchemy_safe)
#      90     if (
#      91         (
#      92             not sqlalchemy_safe
#    (...)
#      97         and ((include and key in include) or key not in exclude)
#      98     ):
#      99         encoded_key = jsonable_encoder(
#     100             key,
#     101             by_alias=by_alias,
#    (...)
#     105             sqlalchemy_safe=sqlalchemy_safe,
#     106         )
# --> 107         encoded_value = jsonable_encoder(
#     108             value,
#     109             by_alias=by_alias,
#     110             exclude_unset=exclude_unset,
#     111             exclude_none=exclude_none,
#     112             custom_encoder=custom_encoder,
#     113             sqlalchemy_safe=sqlalchemy_safe,
#     114         )
#     115         encoded_dict[encoded_key] = encoded_value
#     116 return encoded_dict
#
# File /usr/local/lib/python3.9/site-packages/fastapi/encoders.py:121, in jsonable_encoder(obj, include, exclude, by_alias, skip_defaults, exclude_unset, exclude_defaults, exclude_none, custom_encoder, sqlalchemy_safe)
#     118     encoded_list = []
#     119     for item in obj:
#     120         encoded_list.append(
# --> 121             jsonable_encoder(
#     122                 item,
#     123                 include=include,
#     124                 exclude=exclude,
#     125                 by_alias=by_alias,
#     126                 exclude_unset=exclude_unset,
#     127                 exclude_defaults=exclude_defaults,
#     128                 exclude_none=exclude_none,
#     129                 custom_encoder=custom_encoder,
#     130                 sqlalchemy_safe=sqlalchemy_safe,
#     131             )
#     132         )
#     133     return encoded_list
#     135 if custom_encoder:
#
# File /usr/local/lib/python3.9/site-packages/fastapi/encoders.py:159, in jsonable_encoder(obj, include, exclude, by_alias, skip_defaults, exclude_unset, exclude_defaults, exclude_none, custom_encoder, sqlalchemy_safe)
#     157         errors.append(e)
#     158         raise ValueError(errors)
# --> 159 return jsonable_encoder(
#     160     data,
#     161     by_alias=by_alias,
#     162     exclude_unset=exclude_unset,
#     163     exclude_defaults=exclude_defaults,
#     164     exclude_none=exclude_none,
#     165     custom_encoder=custom_encoder,
#     166     sqlalchemy_safe=sqlalchemy_safe,
#     167 )
#
# File /usr/local/lib/python3.9/site-packages/fastapi/encoders.py:107, in jsonable_encoder(obj, include, exclude, by_alias, skip_defaults, exclude_unset, exclude_defaults, exclude_none, custom_encoder, sqlalchemy_safe)
#      90     if (
#      91         (
#      92             not sqlalchemy_safe
#    (...)
#      97         and ((include and key in include) or key not in exclude)
#      98     ):
#      99         encoded_key = jsonable_encoder(
#     100             key,
#     101             by_alias=by_alias,
#    (...)
#     105             sqlalchemy_safe=sqlalchemy_safe,
#     106         )
# --> 107         encoded_value = jsonable_encoder(
#     108             value,
#     109             by_alias=by_alias,
#     110             exclude_unset=exclude_unset,
#     111             exclude_none=exclude_none,
#     112             custom_encoder=custom_encoder,
#     113             sqlalchemy_safe=sqlalchemy_safe,
#     114         )
#     115         encoded_dict[encoded_key] = encoded_value
#     116 return encoded_dict
#
#     [... skipping similar frames: jsonable_encoder at line 121 (986 times), jsonable_encoder at line 159 (986 times), jsonable_encoder at line 107 (985 times)]
#
# File /usr/local/lib/python3.9/site-packages/fastapi/encoders.py:107, in jsonable_encoder(obj, include, exclude, by_alias, skip_defaults, exclude_unset, exclude_defaults, exclude_none, custom_encoder, sqlalchemy_safe)
#      90     if (
#      91         (
#      92             not sqlalchemy_safe
#    (...)
#      97         and ((include and key in include) or key not in exclude)
#      98     ):
#      99         encoded_key = jsonable_encoder(
#     100             key,
#     101             by_alias=by_alias,
#    (...)
#     105             sqlalchemy_safe=sqlalchemy_safe,
#     106         )
# --> 107         encoded_value = jsonable_encoder(
#     108             value,
#     109             by_alias=by_alias,
#     110             exclude_unset=exclude_unset,
#     111             exclude_none=exclude_none,
#     112             custom_encoder=custom_encoder,
#     113             sqlalchemy_safe=sqlalchemy_safe,
#     114         )
#     115         encoded_dict[encoded_key] = encoded_value
#     116 return encoded_dict
#
# File /usr/local/lib/python3.9/site-packages/fastapi/encoders.py:121, in jsonable_encoder(obj, include, exclude, by_alias, skip_defaults, exclude_unset, exclude_defaults, exclude_none, custom_encoder, sqlalchemy_safe)
#     118     encoded_list = []
#     119     for item in obj:
#     120         encoded_list.append(
# --> 121             jsonable_encoder(
#     122                 item,
#     123                 include=include,
#     124                 exclude=exclude,
#     125                 by_alias=by_alias,
#     126                 exclude_unset=exclude_unset,
#     127                 exclude_defaults=exclude_defaults,
#     128                 exclude_none=exclude_none,
#     129                 custom_encoder=custom_encoder,
#     130                 sqlalchemy_safe=sqlalchemy_safe,
#     131             )
#     132         )
#     133     return encoded_list
#     135 if custom_encoder:
#
# File /usr/local/lib/python3.9/site-packages/fastapi/encoders.py:159, in jsonable_encoder(obj, include, exclude, by_alias, skip_defaults, exclude_unset, exclude_defaults, exclude_none, custom_encoder, sqlalchemy_safe)
#     157         errors.append(e)
#     158         raise ValueError(errors)
# --> 159 return jsonable_encoder(
#     160     data,
#     161     by_alias=by_alias,
#     162     exclude_unset=exclude_unset,
#     163     exclude_defaults=exclude_defaults,
#     164     exclude_none=exclude_none,
#     165     custom_encoder=custom_encoder,
#     166     sqlalchemy_safe=sqlalchemy_safe,
#     167 )
#
# File /usr/local/lib/python3.9/site-packages/fastapi/encoders.py:99, in jsonable_encoder(obj, include, exclude, by_alias, skip_defaults, exclude_unset, exclude_defaults, exclude_none, custom_encoder, sqlalchemy_safe)
#      89 for key, value in obj.items():
#      90     if (
#      91         (
#      92             not sqlalchemy_safe
#    (...)
#      97         and ((include and key in include) or key not in exclude)
#      98     ):
# ---> 99         encoded_key = jsonable_encoder(
#     100             key,
#     101             by_alias=by_alias,
#     102             exclude_unset=exclude_unset,
#     103             exclude_none=exclude_none,
#     104             custom_encoder=custom_encoder,
#     105             sqlalchemy_safe=sqlalchemy_safe,
#     106         )
#     107         encoded_value = jsonable_encoder(
#     108             value,
#     109             by_alias=by_alias,
#    (...)
#     113             sqlalchemy_safe=sqlalchemy_safe,
#     114         )
#     115         encoded_dict[encoded_key] = encoded_value
#
# File /usr/local/lib/python3.9/site-packages/fastapi/encoders.py:52, in jsonable_encoder(obj, include, exclude, by_alias, skip_defaults, exclude_unset, exclude_defaults, exclude_none, custom_encoder, sqlalchemy_safe)
#      50 if exclude is not None and not isinstance(exclude, set):
#      51     exclude = set(exclude)
# ---> 52 if isinstance(obj, BaseModel):
#      53     encoder = getattr(obj.Config, "json_encoders", {})
#      54     if custom_encoder:
#
# File /usr/local/lib/python3.9/abc.py:119, in ABCMeta.__instancecheck__(cls, instance)
#     117 def __instancecheck__(cls, instance):
#     118     """Override for isinstance(instance, cls)."""
# --> 119     return _abc_instancecheck(cls, instance)
#
# RecursionError: maximum recursion depth exceeded in comparison

# %%
jsonable_encoder(tags[2].notes)
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Input In [40], in <cell line: 1>()
# ----> 1 jsonable_encoder(tags[2].notes)
#
# File /usr/local/lib/python3.9/site-packages/fastapi/encoders.py:121, in jsonable_encoder(obj, include, exclude, by_alias, skip_defaults, exclude_unset, exclude_defaults, exclude_none, custom_encoder, sqlalchemy_safe)
#     118     encoded_list = []
#     119     for item in obj:
#     120         encoded_list.append(
# --> 121             jsonable_encoder(
#     122                 item,
#     123                 include=include,
#     124                 exclude=exclude,
#     125                 by_alias=by_alias,
#     126                 exclude_unset=exclude_unset,
#     127                 exclude_defaults=exclude_defaults,
#     128                 exclude_none=exclude_none,
#     129                 custom_encoder=custom_encoder,
#     130                 sqlalchemy_safe=sqlalchemy_safe,
#     131             )
#     132         )
#     133     return encoded_list
#     135 if custom_encoder:
#
# File /usr/local/lib/python3.9/site-packages/fastapi/encoders.py:159, in jsonable_encoder(obj, include, exclude, by_alias, skip_defaults, exclude_unset, exclude_defaults, exclude_none, custom_encoder, sqlalchemy_safe)
#     157         errors.append(e)
#     158         raise ValueError(errors)
# --> 159 return jsonable_encoder(
#     160     data,
#     161     by_alias=by_alias,
#     162     exclude_unset=exclude_unset,
#     163     exclude_defaults=exclude_defaults,
#     164     exclude_none=exclude_none,
#     165     custom_encoder=custom_encoder,
#     166     sqlalchemy_safe=sqlalchemy_safe,
#     167 )
#
# File /usr/local/lib/python3.9/site-packages/fastapi/encoders.py:107, in jsonable_encoder(obj, include, exclude, by_alias, skip_defaults, exclude_unset, exclude_defaults, exclude_none, custom_encoder, sqlalchemy_safe)
#      90     if (
#      91         (
#      92             not sqlalchemy_safe
#    (...)
#      97         and ((include and key in include) or key not in exclude)
#      98     ):
#      99         encoded_key = jsonable_encoder(
#     100             key,
#     101             by_alias=by_alias,
#    (...)
#     105             sqlalchemy_safe=sqlalchemy_safe,
#     106         )
# --> 107         encoded_value = jsonable_encoder(
#     108             value,
#     109             by_alias=by_alias,
#     110             exclude_unset=exclude_unset,
#     111             exclude_none=exclude_none,
#     112             custom_encoder=custom_encoder,
#     113             sqlalchemy_safe=sqlalchemy_safe,
#     114         )
#     115         encoded_dict[encoded_key] = encoded_value
#     116 return encoded_dict
#
# File /usr/local/lib/python3.9/site-packages/fastapi/encoders.py:121, in jsonable_encoder(obj, include, exclude, by_alias, skip_defaults, exclude_unset, exclude_defaults, exclude_none, custom_encoder, sqlalchemy_safe)
#     118     encoded_list = []
#     119     for item in obj:
#     120         encoded_list.append(
# --> 121             jsonable_encoder(
#     122                 item,
#     123                 include=include,
#     124                 exclude=exclude,
#     125                 by_alias=by_alias,
#     126                 exclude_unset=exclude_unset,
#     127                 exclude_defaults=exclude_defaults,
#     128                 exclude_none=exclude_none,
#     129                 custom_encoder=custom_encoder,
#     130                 sqlalchemy_safe=sqlalchemy_safe,
#     131             )
#     132         )
#     133     return encoded_list
#     135 if custom_encoder:
#
# File /usr/local/lib/python3.9/site-packages/fastapi/encoders.py:159, in jsonable_encoder(obj, include, exclude, by_alias, skip_defaults, exclude_unset, exclude_defaults, exclude_none, custom_encoder, sqlalchemy_safe)
#     157         errors.append(e)
#     158         raise ValueError(errors)
# --> 159 return jsonable_encoder(
#     160     data,
#     161     by_alias=by_alias,
#     162     exclude_unset=exclude_unset,
#     163     exclude_defaults=exclude_defaults,
#     164     exclude_none=exclude_none,
#     165     custom_encoder=custom_encoder,
#     166     sqlalchemy_safe=sqlalchemy_safe,
#     167 )
#
# File /usr/local/lib/python3.9/site-packages/fastapi/encoders.py:107, in jsonable_encoder(obj, include, exclude, by_alias, skip_defaults, exclude_unset, exclude_defaults, exclude_none, custom_encoder, sqlalchemy_safe)
#      90     if (
#      91         (
#      92             not sqlalchemy_safe
#    (...)
#      97         and ((include and key in include) or key not in exclude)
#      98     ):
#      99         encoded_key = jsonable_encoder(
#     100             key,
#     101             by_alias=by_alias,
#    (...)
#     105             sqlalchemy_safe=sqlalchemy_safe,
#     106         )
# --> 107         encoded_value = jsonable_encoder(
#     108             value,
#     109             by_alias=by_alias,
#     110             exclude_unset=exclude_unset,
#     111             exclude_none=exclude_none,
#     112             custom_encoder=custom_encoder,
#     113             sqlalchemy_safe=sqlalchemy_safe,
#     114         )
#     115         encoded_dict[encoded_key] = encoded_value
#     116 return encoded_dict
#
#     [... skipping similar frames: jsonable_encoder at line 121 (986 times), jsonable_encoder at line 159 (986 times), jsonable_encoder at line 107 (985 times)]
#
# File /usr/local/lib/python3.9/site-packages/fastapi/encoders.py:107, in jsonable_encoder(obj, include, exclude, by_alias, skip_defaults, exclude_unset, exclude_defaults, exclude_none, custom_encoder, sqlalchemy_safe)
#      90     if (
#      91         (
#      92             not sqlalchemy_safe
#    (...)
#      97         and ((include and key in include) or key not in exclude)
#      98     ):
#      99         encoded_key = jsonable_encoder(
#     100             key,
#     101             by_alias=by_alias,
#    (...)
#     105             sqlalchemy_safe=sqlalchemy_safe,
#     106         )
# --> 107         encoded_value = jsonable_encoder(
#     108             value,
#     109             by_alias=by_alias,
#     110             exclude_unset=exclude_unset,
#     111             exclude_none=exclude_none,
#     112             custom_encoder=custom_encoder,
#     113             sqlalchemy_safe=sqlalchemy_safe,
#     114         )
#     115         encoded_dict[encoded_key] = encoded_value
#     116 return encoded_dict
#
# File /usr/local/lib/python3.9/site-packages/fastapi/encoders.py:121, in jsonable_encoder(obj, include, exclude, by_alias, skip_defaults, exclude_unset, exclude_defaults, exclude_none, custom_encoder, sqlalchemy_safe)
#     118     encoded_list = []
#     119     for item in obj:
#     120         encoded_list.append(
# --> 121             jsonable_encoder(
#     122                 item,
#     123                 include=include,
#     124                 exclude=exclude,
#     125                 by_alias=by_alias,
#     126                 exclude_unset=exclude_unset,
#     127                 exclude_defaults=exclude_defaults,
#     128                 exclude_none=exclude_none,
#     129                 custom_encoder=custom_encoder,
#     130                 sqlalchemy_safe=sqlalchemy_safe,
#     131             )
#     132         )
#     133     return encoded_list
#     135 if custom_encoder:
#
# File /usr/local/lib/python3.9/site-packages/fastapi/encoders.py:159, in jsonable_encoder(obj, include, exclude, by_alias, skip_defaults, exclude_unset, exclude_defaults, exclude_none, custom_encoder, sqlalchemy_safe)
#     157         errors.append(e)
#     158         raise ValueError(errors)
# --> 159 return jsonable_encoder(
#     160     data,
#     161     by_alias=by_alias,
#     162     exclude_unset=exclude_unset,
#     163     exclude_defaults=exclude_defaults,
#     164     exclude_none=exclude_none,
#     165     custom_encoder=custom_encoder,
#     166     sqlalchemy_safe=sqlalchemy_safe,
#     167 )
#
# File /usr/local/lib/python3.9/site-packages/fastapi/encoders.py:99, in jsonable_encoder(obj, include, exclude, by_alias, skip_defaults, exclude_unset, exclude_defaults, exclude_none, custom_encoder, sqlalchemy_safe)
#      89 for key, value in obj.items():
#      90     if (
#      91         (
#      92             not sqlalchemy_safe
#    (...)
#      97         and ((include and key in include) or key not in exclude)
#      98     ):
# ---> 99         encoded_key = jsonable_encoder(
#     100             key,
#     101             by_alias=by_alias,
#     102             exclude_unset=exclude_unset,
#     103             exclude_none=exclude_none,
#     104             custom_encoder=custom_encoder,
#     105             sqlalchemy_safe=sqlalchemy_safe,
#     106         )
#     107         encoded_value = jsonable_encoder(
#     108             value,
#     109             by_alias=by_alias,
#    (...)
#     113             sqlalchemy_safe=sqlalchemy_safe,
#     114         )
#     115         encoded_dict[encoded_key] = encoded_value
#
# File /usr/local/lib/python3.9/site-packages/fastapi/encoders.py:52, in jsonable_encoder(obj, include, exclude, by_alias, skip_defaults, exclude_unset, exclude_defaults, exclude_none, custom_encoder, sqlalchemy_safe)
#      50 if exclude is not None and not isinstance(exclude, set):
#      51     exclude = set(exclude)
# ---> 52 if isinstance(obj, BaseModel):
#      53     encoder = getattr(obj.Config, "json_encoders", {})
#      54     if custom_encoder:
#
# File /usr/local/lib/python3.9/abc.py:119, in ABCMeta.__instancecheck__(cls, instance)
#     117 def __instancecheck__(cls, instance):
#     118     """Override for isinstance(instance, cls)."""
# --> 119     return _abc_instancecheck(cls, instance)
#
# RecursionError: maximum recursion depth exceeded in comparison
